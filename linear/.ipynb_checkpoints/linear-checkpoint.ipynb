# %% [markdown]
# # Machine Learning Assignment # 02 | Faizan Ikram - 2018-UET-NML-27

# %% [markdown]
# # 1 - Linear Network

# %%
import tensorflow as tf
from tensorflow import keras

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('./data/train.csv')
np.random.shuffle(train_df.values)

print('\nData: ', train_df.head())
# Out:
# Data:            x         y  color
# 0  0.761140 -0.679535    1.0
# 1  1.873801  1.054104    1.0
# 2  1.403993  0.449433    1.0
# 3  1.955581  2.646052    0.0
# 4  1.116103 -0.083738    1.0

# %% [markdown]
# # Plotting Data

# %%
df1 = train_df[train_df.color==0]
df2 = train_df[train_df.color==1]

plt.scatter(df1.x, df1.y, marker = '.', color='red')
plt.scatter(df2.x, df2.y, marker = '.', color='blue')
plt.show()

# %% [markdown]
# # Sequencial API

# %%
# #Sequencial API (Seq: We can map One Input to One Output - Not Flexible)
#model = keras.Sequential([
#keras.layers.Dense(4, input_shape=(2,), activation='relu'), 
#keras.layers.Dense(2, activation='sigmoid')])

# %% [markdown]
# # Functional API

# %%
# Functional API (Func: It is more flexible as it can handle multiple input and multiple output - More Flexible)
inputs = keras.Input(shape=(2,))
x = keras.layers.Dense(4, activation='relu', name='First_layer')(inputs)
outputs = keras.layers.Dense(2, activation='sigmoid')(x)
model = keras.Model(inputs=inputs, outputs=outputs)

print(model.summary())   # Network information -> Layers -> Nodes -> Parameters
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# First_layer (Dense)          (None, 4)                 12
# _________________________________________________________________
# dense (Dense)                (None, 2)                 10
# =================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Modal Training

# %%
model.compile(optimizer='adam', loss=keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

# Set the input shape
feature_vector_shape = len(train_df.values[0])
input_shape = (feature_vector_shape,)
print(f'Feature shape: {input_shape}')

y = train_df.color.values
x = np.column_stack((train_df.x.values, train_df.y.values))
# Out:
# Feature shape: (3,)

# %%
model.fit(x, y, batch_size=4,  epochs=5, verbose=2)
# Out:
# Epoch 1/5
# 1000/1000 - 1s - loss: 0.4850 - accuracy: 0.6827
# Epoch 2/5
# 1000/1000 - 1s - loss: 0.0849 - accuracy: 1.0000
# Epoch 3/5
# 1000/1000 - 1s - loss: 0.0249 - accuracy: 1.0000
# Epoch 4/5
# 1000/1000 - 1s - loss: 0.0118 - accuracy: 1.0000
# Epoch 5/5
# 1000/1000 - 1s - loss: 0.0066 - accuracy: 1.0000

# %% [markdown]
# # Test Data Evaluation

# %%
test_df = pd.read_csv('./data/test.csv')
test_x = np.column_stack((test_df.x.values, test_df.y.values))

print("EVALUATION")
model.evaluate(test_x, test_df.color.values)
# Out:
# EVALUATION
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 1.0000
# [0.004967638291418552, 1.0]

# %% [markdown]
# # Test Data Scatter Plot

# %%
plt.scatter(test_df.x,test_df.y)

df1 = test_df[test_df.color==0]
df2 = test_df[test_df.color==1]

plt.scatter(df1.x, df1.y, marker = '+', color='red')
plt.scatter(df2.x, df2.y, marker = '+', color='blue')

plt.show()

# %% [markdown]
# # Plotting Hyperplane ( Training Data )

# %%
from mlxtend.plotting import plot_decision_regions
from sklearn.svm import SVC
from sklearn import svm

svm = SVC(C=0.5, kernel='linear')
svm.fit(x, y)

# Plot decision boundary
a = plot_decision_regions(x, y, clf=svm, legend=2)
handles, labels = a.get_legend_handles_labels()

plt.show()

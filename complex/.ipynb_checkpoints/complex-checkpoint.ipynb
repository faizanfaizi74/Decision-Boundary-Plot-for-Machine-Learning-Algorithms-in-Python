# %% [markdown]
# # 5 - Complex Network

# %%
import tensorflow as tf
from tensorflow import keras

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('./data/train.csv')
np.random.shuffle(train_df.values)

print(train_df.head())
# Out:
#           x         y  color
# 0  1.155520  4.939715    0.0
# 1 -0.114852 -1.362734    0.0
# 2 -2.721549  3.036756    1.0
# 3  4.008203 -2.140839    0.0
# 4  2.819329 -0.862197    0.0

# %% [markdown]
# # Plotting Data

# %%
df0 = train_df[train_df.color==0]
df1 = train_df[train_df.color==1]

plt.scatter(df0.x, df0.y, marker = '.', color='red')
plt.scatter(df1.x, df1.y, marker = '.', color='blue')

plt.show()

# %% [markdown]
# # Sequencial API

# %%
# model = keras.Sequential([
# 	keras.layers.Dense(256, input_shape=(2,), activation='relu'),
# 	keras.layers.Dropout(0.4),
# 	keras.layers.Dense(256, activation='relu'),
# 	keras.layers.Dropout(0.4),
# 	keras.layers.Dense(256, activation='relu'),
# 	keras.layers.Dense(2, activation='sigmoid')])

# %% [markdown]
# # Functional API

# %%
# Functional API (Func: It is more flexible as it can handle multiple input and multiple output - More Flexible)
inputs = keras.Input(shape=(2,))
x = keras.layers.Dense(256, activation='relu', name='First_layer')(inputs)
#x = keras.layers.Dropout(0.4)(x)
x = keras.layers.Dense(256, activation='relu', name='Second_layer')(x)
#x = keras.layers.Dropout(0.4)(x)
x = keras.layers.Dense(256, activation='relu', name='Third_layer')(x)
outputs = keras.layers.Dense(2, activation='sigmoid')(x)
model = keras.Model(inputs=inputs, outputs=outputs)

print(model.summary())   # Network information -> Layers -> Nodes -> Parameters
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# First_layer (Dense)          (None, 256)               768
# _________________________________________________________________
# Second_layer (Dense)         (None, 256)               65792
# _________________________________________________________________
# Third_layer (Dense)          (None, 256)               65792
# _________________________________________________________________
# dense (Dense)                (None, 2)                 514
# =================================================================
# Total params: 132,866
# Trainable params: 132,866
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Modal Training

# %%
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

x = np.column_stack((train_df.x.values, train_df.y.values))

# %%
model.fit(x, train_df.color.values, batch_size=32, epochs=20)
# Out:
# Epoch 1/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5895 - accuracy: 0.6934
# Epoch 2/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5349 - accuracy: 0.7577
# Epoch 3/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5269 - accuracy: 0.7624
# Epoch 4/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5155 - accuracy: 0.7725
# Epoch 5/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5003 - accuracy: 0.7961
# Epoch 6/20
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4911 - accuracy: 0.8047
# Epoch 7/20
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4835 - accuracy: 0.8140
# Epoch 8/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4746 - accuracy: 0.8236
# Epoch 9/20
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4639 - accuracy: 0.8417
# Epoch 10/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4580 - accuracy: 0.8471
# Epoch 11/20
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4522 - accuracy: 0.8523
# Epoch 12/20
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4533 - accuracy: 0.8490
# Epoch 13/20
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4497 - accuracy: 0.8533
# Epoch 14/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4415 - accuracy: 0.8618
# Epoch 15/20
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4399 - accuracy: 0.8648
# Epoch 16/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4416 - accuracy: 0.8630
# Epoch 17/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8693
# Epoch 18/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4344 - accuracy: 0.8722
# Epoch 19/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4282 - accuracy: 0.8811
# Epoch 20/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4272 - accuracy: 0.8824

# %% [markdown]
# # Test Data Evaluation

# %%
test_df = pd.read_csv('./data/test.csv')
test_x = np.column_stack((test_df.x.values, test_df.y.values))

print("EVALUATION")
model.evaluate(test_x, test_df.color.values)
# Out:
# EVALUATION
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4128 - accuracy: 0.9000
# [0.41279155015945435, 0.8999999761581421]

# %% [markdown]
# # Plotting Test Data

# %%
df0 = test_df[test_df.color==0]
df1 = test_df[test_df.color==1]

plt.scatter(df0.x, df0.y, marker = '+', color='red')
plt.scatter(df1.x, df1.y, marker = '+', color='blue')

plt.show()

# %% [markdown]
# # SVM Modal Fitting

# %%
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC
from sklearn import svm

# %%
xx, yy = np.meshgrid(np.linspace(-3, 3, 500), np.linspace(-3, 3, 500))
np.random.seed(0)

# fit the model
clf = svm.NuSVC(gamma="auto")
clf.fit(x, train_df.color.values)
# Out:
# NuSVC(gamma='auto')

# %% [markdown]
# # Plotting Hyperplane ( Training Data )

# %%
# plot the decision function for each datapoint on the grid
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.imshow(Z, interpolation="nearest", extent=(xx.min(), xx.max(), yy.min(), yy.max()), 
           aspect="auto", origin="lower", cmap=plt.cm.PuOr_r,)

contours = plt.contour(xx, yy, Z, levels=[0], linewidths=2,)

plt.scatter(x[:, 0], x[:, 1], s=30, c=train_df.color.values, cmap='winter', edgecolors="k")
plt.xticks(())
plt.yticks(())
plt.axis([-2, 2, -2, 2])
plt.show()

# %% [markdown]
# # Plotting Hyperplane ( Test Data )

# %%
# plot the decision function for each datapoint on the grid
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.imshow(Z, interpolation="nearest", extent=(xx.min(), xx.max(), yy.min(), yy.max()), 
           aspect="auto", origin="lower", cmap=plt.cm.PuOr_r,)

contours = plt.contour(xx, yy, Z, levels=[0], linewidths=2,)

plt.scatter(test_x[:, 0], test_x[:, 1], s=30, c=test_df.color.values, cmap='winter', marker='+', edgecolors="k")
plt.xticks(())
plt.yticks(())
plt.axis([-2, 2, -2, 2])
plt.show()
